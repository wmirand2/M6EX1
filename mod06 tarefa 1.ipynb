# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns


# %matplotlib inline
# %matplotlib notebook

# %%
sinasc = pd.read_csv('SINASC_RO_2019.csv')
sinasc.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
plt.rc('figure', figsize=(10, 8))
fig, axes = plt.subplots(1, 2)

sns.countplot(ax = axes[0], x='APGAR1', data=sinasc)
sns.countplot(ax = axes[1], x='APGAR5', data=sinasc)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <Axes: xlabel='APGAR5', ylabel='count'>

# %%
plt.rc('figure', figsize=(5, 5))
fig, axes = plt.subplots(1, 1)
sns.countplot(x='SEXO', data=sinasc)
# Out:
# <img src="data:image/png;base64,..." width="500">
# <Axes: xlabel='SEXO', ylabel='count'>

# %%
plt.rc('figure', figsize=(7, 5))
fig, axes = plt.subplots(1, 1)
sns.countplot(x='ESTCIVMAE', data=sinasc)
# Out:
# <img src="data:image/png;base64,..." width="700">
# <Axes: xlabel='ESTCIVMAE', ylabel='count'>

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
plt.rc('figure', figsize=(7, 5))
fig, axes = plt.subplots(1, 1)

sns.barplot(x='CONSULTAS', y='APGAR5', data= , ci = None)
# Out:
# <img src="data:image/png;base64,..." width="700">
# C:\Users\willi\AppData\Local\Temp\ipykernel_20096\3052940355.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='CONSULTAS', y='APGAR5', data=sinasc, ci = None)
# <Axes: xlabel='CONSULTAS', ylabel='APGAR5'>

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.rc('figure', figsize=(16, 8))
fig, axes = plt.subplots(2, 2)
plt.subplots_adjust( hspace=1)

chart1 = sns.countplot(ax = axes[0,0], x='SEXO', data=sinasc)
chart2 = sns.countplot(ax = axes[0,1], x='GESTACAO', data=sinasc)
chart3 = sns.countplot(ax = axes[1,0], x='ESTCIVMAE', data=sinasc)
chart4 = sns.countplot(ax = axes[1,1], x='CONSULTAS', data=sinasc)

labels_chart2 = chart2.set_xticklabels(chart2.get_xticklabels(),rotation=45, horizontalalignment='right')
# Out:
# <img src="data:image/png;base64,..." width="1600">
